# %%
# This file contains functions to build a dataset from the generate_data file

# %%
import generate_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import generate_data
#
# ModuleNotFoundError: No module named 'generate_data'

# %%
# %run generate_data.ipynb # may need to change this when becomes an API Client

# %%
## importing necessary libraries 
import pandas as pd
import numpy as np  
import re

# %%
today_lst = today_data()
yesterday_lst = yesterday_data()
tomorrow_lst = tomorrow_data()

# %%
df = pd.DataFrame(lst_sun_signs)
df.head()
# Out:
#         0
# 0   aries
# 1  taurus
# 2  gemini
# 3  cancer
# 4     leo

# %%
today_lst[0].text
# Out:
# '{"date_range": "Mar 21 - Apr 20", "current_date": "December 8, 2022", "description": "Being critical of yourself won\'t get you anywhere. You know that, but that doesn\'t mean you won\'t do it, especially if you\'re feeling guilty about something. Before you really get going, think about your good qualities.", "compatibility": "Pisces", "mood": "Confidence", "color": "Navy Blue", "lucky_number": "83", "lucky_time": "11pm"}\n'

# %%
# extract date from each lst

def extract_date(txt):
    date = re.findall(r'"current_date":\s"(.+[0-9]{4})', txt)
    return date

def date_for_each():
    lst = yesterday_lst + today_lst + tomorrow_lst 
    lst_dates = []
    for i in lst:
        lst_dates.append(extract_date(i.text)[0])
    return lst_dates

# %%
# extract description from each lst

def extract_description(txt):
    date = re.findall(r'"description":\s"(.+\.)', txt)
    return date

def description_for_each():
    lst = yesterday_lst + today_lst + tomorrow_lst 
    lst_description = []
    for i in lst:
        lst_description.append(extract_description(i.text)[0])
    return lst_description

# %%
# extract compatibility from each lst

def extract_compatibility(txt):
    date = re.findall(r'"compatibility":\s"([A-z]{3,11})', txt)
    return date

def compatibility_for_each():
    lst = yesterday_lst + today_lst + tomorrow_lst 
    lst_compatibility = []
    for i in lst:
        lst_compatibility.append(extract_compatibility(i.text)[0])
    return lst_compatibility

# %%
# extract mood from each lst

def extract_mood(txt):
    date = re.findall(r'"mood":\s"([A-z]+)', txt)
    return date

def mood_for_each():
    lst = yesterday_lst + today_lst + tomorrow_lst 
    lst_mood = []
    for i in lst:
        lst_mood.append(extract_mood(i.text)[0])
    return lst_mood

# %%
# extract color from each lst

def extract_color(txt):
    date = re.findall(r'"color":\s"([A-z]+?\s?[A-z]+)', txt)
    return date

def color_for_each():
    lst = yesterday_lst + today_lst + tomorrow_lst 
    lst_color = []
    for i in lst:
        lst_color.append(extract_color(i.text)[0])
    return lst_color

# %%
# extract lucky_number from each lst

def extract_lucky_number(txt):
    lucky_number = re.findall(r'"lucky_number":\s"([0-9]+)', txt)
    return lucky_number

def lucky_number_for_each():
    lst = yesterday_lst + today_lst + tomorrow_lst 
    lst_lucky_number = []
    for i in lst:
        lst_lucky_number.append(extract_lucky_number(i.text)[0])
    return lst_lucky_number

# %%
# extract lucky_time from each lst

def extract_lucky_time(txt):
    lucky_time = re.findall(r'"lucky_time":\s"([0-9apm]+)', txt)
    return lucky_time

def lucky_time_for_each():
    lst = yesterday_lst + today_lst + tomorrow_lst 
    lst_lucky_time = []
    for i in lst:
        lst_lucky_time.append(extract_lucky_time(i.text)[0])
    return lst_lucky_time

# %%
lst = lst_sun_signs * 3
df = pd.DataFrame({
    'Sun Sign': lst,
    'Date': date_for_each(),
    'Description': description_for_each(),
    'Compatibility': compatibility_for_each(),
    'Mood': mood_for_each(),
    'Color': color_for_each(),
    'Lucky Number': lucky_number_for_each(),
    'Lucky Time': lucky_time_for_each()
    
})
df
# Out:
#        Sun Sign              Date  \
# 0         aries  December 7, 2022
# 1        taurus  December 7, 2022
# 2        gemini  December 7, 2022
# 3        cancer  December 7, 2022
# 4           leo  December 7, 2022
# 5         virgo  December 7, 2022
# 6         libra  December 7, 2022
# 7       scorpio  December 7, 2022
# 8   sagittarius  December 7, 2022
# 9     capricorn  December 7, 2022
# 10     aquarius  December 7, 2022
# 11        aries  December 8, 2022
# 12       taurus  December 8, 2022
# 13       gemini  December 8, 2022
# 14       cancer  December 8, 2022
# 15          leo  December 8, 2022
# 16        virgo  December 8, 2022
# 17        libra  December 8, 2022
# 18      scorpio  December 8, 2022
# 19  sagittarius  December 8, 2022
# 20    capricorn  December 8, 2022
# 21     aquarius  December 8, 2022
# 22        aries  December 9, 2022
# 23       taurus  December 9, 2022
# 24       gemini  December 9, 2022
# 25       cancer  December 9, 2022
# 26          leo  December 9, 2022
# 27        virgo  December 9, 2022
# 28        libra  December 9, 2022
# 29      scorpio  December 9, 2022
# 30  sagittarius  December 9, 2022
# 31    capricorn  December 9, 2022
# 32     aquarius  December 9, 2022
#
#                                           Description Compatibility  \
# 0   It's not your imagination, and you're not para...         Libra
# 1   Ready to fall in love? Or back in love? You'd ...        Pisces
# 2   Okay. It's time for you to talk about what's k...         Libra
# 3   You're as meticulous as a sign can possibly be...       Scorpio
# 4   Not in the mood to leave the house? Pull on yo...     Capricorn
# 5   You're the most sociable and outgoing of the s...         Aries
# 6   Contrary to astrological opinion, getting up c...   Sagittarius
# 7   Woe betide anyone who wants to start something...        Taurus
# 8   Choosing friends isn't something you take ligh...      Aquarius
# 9   You're not usually the type to show off -- not...         Libra
# 10  Taking care of business may not be what you'd ...        Taurus
# 11  Being critical of yourself won't get you anywh...        Pisces
# 12  That romantic roll you're on isn't going anywh...        Gemini
# 13  You know that emotion you're feeling so strong...       Scorpio
# 14  There's more than one way to clean up. Whether...   Sagittarius
# 15  You have a strong urge to continue hibernating...     Capricorn
# 16  Still not feeling fit for human interaction? I...       Scorpio
# 17  Still trying to convince yourself that the per...       Scorpio
# 18  You haven't let a single opportunity for a qui...        Gemini
# 19  Still looking for just the right person to add...        Pisces
# 20  Your primary partner, or someone who aspires t...   Sagittarius
# 21  With the possible exception of an extremely st...        Gemini
# 22  Feel better about yourself now? You will, soon...         Virgo
# 23  Someone you see on a daily basis hasn't just c...        Cancer
# 24  A financial situation seems to be turning quit...      Aquarius
# 25  When you're as upset as you are now, you don't...         Virgo
# 26  This may be a tricky day, but if you're smart ...   Sagittarius
# 27  Variety isn't the only spice life has to offer...        Taurus
# 28  'Sudden' is definitely your middle name -- and...        Gemini
# 29  Being nice to your family members -- especiall...        Taurus
# 30  Love may not be in the air, but romance certai...        Cancer
# 31  It's time to snuggle up and spend some quality...        Gemini
# 32  You're feeling both selfless and selfish when ...         Virgo
#
#             Mood   Color Lucky Number Lucky Time
# 0       Charming  Shadow           47        7am
# 1          Loved     Red           91       11pm
# 2       Pleasant  Silver            0        9pm
# 3     Aggressive    Navy           38        6am
# 4        Relaxed    Rose            8        2pm
# 5    Independent  Copper           36        6pm
# 6        Relaxed    Blue           62        5pm
# 7       Cautious   Brown           57       10am
# 8        Sincere    Navy           19        5am
# 9     Confidence     Red           59        7pm
# 10  Accomplished    Rose            7        9am
# 11    Confidence    Navy           83       11pm
# 12         Happy    Teal           23       10pm
# 13         Moody     Sky           70        2pm
# 14   Rejuvenated    Blue           77        5am
# 15      Peaceful    Teal           26        2pm
# 16       Relaxed     Red           20        5am
# 17      Charming    Teal            7        7pm
# 18      Cautious  Spring           31       12am
# 19      Pleasant  Orchid           48        2pm
# 20      Charming    Pink           29        5am
# 21    Productive    Blue            3        5am
# 22       Helpful  Silver           26        2am
# 23      Charming    Pink           78        1pm
# 24      Helpless    Gold           74       10am
# 25          Calm  Silver           43        9am
# 26          Calm    Gold           42        4pm
# 27      Creative    Rose            6       11pm
# 28         Smart  Silver           26        7am
# 29    Thoughtful  Purple           68        6am
# 30         Sweet    Navy           30        5am
# 31         Sweet  Silver           79        9pm
# 32         Loved  Copper           76        4pm
